# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: fastapi in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (0.111.0)
# Requirement already satisfied: uvicorn in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (0.30.1)
# Requirement already satisfied: asyncio in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (3.4.3)
# Requirement already satisfied: python-dotenv in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (0.21.0)
# Requirement already satisfied: manim in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (0.18.1)
# Requirement already satisfied: moviepy in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (1.0.3)
# Collecting openai (from -r requirements.txt (line 8))
#   Downloading openai-1.35.3-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: hume[stream] in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from fastapi->-r requirements.txt (line 1)) (0.37.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from fastapi->-r requirements.txt (line 1)) (2.7.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from fastapi->-r requirements.txt (line 1)) (4.11.0)
# Requirement already satisfied: fastapi-cli>=0.0.2 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from fastapi->-r requirements.txt (line 1)) (0.0.4)
# Requirement already satisfied: httpx>=0.23.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from fastapi->-r requirements.txt (line 1)) (0.27.0)
# Requirement already satisfied: jinja2>=2.11.2 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from fastapi->-r requirements.txt (line 1)) (3.1.3)
# Requirement already satisfied: python-multipart>=0.0.7 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from fastapi->-r requirements.txt (line 1)) (0.0.9)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from fastapi->-r requirements.txt (line 1)) (5.4.0)
# Requirement already satisfied: orjson>=3.2.1 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from fastapi->-r requirements.txt (line 1)) (3.10.5)
# Requirement already satisfied: email_validator>=2.0.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from fastapi->-r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: click>=7.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from uvicorn->-r requirements.txt (line 2)) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from uvicorn->-r requirements.txt (line 2)) (0.14.0)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.2.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from hume[stream]->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: pydub<0.26.0,>=0.25.1 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from hume[stream]->-r requirements.txt (line 5)) (0.25.1)
# Requirement already satisfied: simpleaudio<2.0.0,>=1.0.4 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from hume[stream]->-r requirements.txt (line 5)) (1.0.4)
# Requirement already satisfied: sounddevice<0.5.0,>=0.4.6 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from hume[stream]->-r requirements.txt (line 5)) (0.4.7)
# Requirement already satisfied: websockets<13.0,>=12.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from hume[stream]->-r requirements.txt (line 5)) (12.0)
# Requirement already satisfied: Pillow>=9.1 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (10.3.0)
# Requirement already satisfied: Pygments>=2.0.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (2.15.1)
# Requirement already satisfied: cloup>=2.0.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (3.0.5)
# Requirement already satisfied: decorator>=4.3.2 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (4.4.2)
# Requirement already satisfied: isosurfaces>=0.1.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (0.1.2)
# Requirement already satisfied: manimpango<1.0.0,>=0.5.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (0.5.0)
# Requirement already satisfied: mapbox-earcut>=1.0.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (1.0.1)
# Requirement already satisfied: moderngl<6.0.0,>=5.0.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (5.10.0)
# Requirement already satisfied: moderngl-window>=2.0.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (2.4.6)
# Requirement already satisfied: networkx>=2.6 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (3.1)
# Requirement already satisfied: numpy>=1.26 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (1.26.4)
# Requirement already satisfied: pycairo<2.0.0,>=1.13 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (1.26.1)
# Requirement already satisfied: rich>=12.0.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (13.3.5)
# Requirement already satisfied: scipy>=1.6.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (1.13.0)
# Requirement already satisfied: screeninfo>=0.7 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (0.8.1)
# Requirement already satisfied: skia-pathops>=0.7.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (0.8.0.post1)
# Requirement already satisfied: srt>=3.0.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (3.5.3)
# Requirement already satisfied: svgelements>=1.8.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (1.9.6)
# Requirement already satisfied: tqdm>=4.0.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (4.66.2)
# Requirement already satisfied: watchdog>=2.0.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (2.1.6)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from moviepy->-r requirements.txt (line 7)) (2.31.0)
# Requirement already satisfied: proglog<=1.0.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from moviepy->-r requirements.txt (line 7)) (0.1.10)
# Requirement already satisfied: imageio<3.0,>=2.5 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from moviepy->-r requirements.txt (line 7)) (2.33.1)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from moviepy->-r requirements.txt (line 7)) (0.5.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from openai->-r requirements.txt (line 8)) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from openai->-r requirements.txt (line 8)) (1.9.0)
# Requirement already satisfied: sniffio in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from openai->-r requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 8)) (3.7)
# Requirement already satisfied: dnspython>=2.0.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from email_validator>=2.0.0->fastapi->-r requirements.txt (line 1)) (2.6.1)
# Requirement already satisfied: typer>=0.12.3 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from fastapi-cli>=0.0.2->fastapi->-r requirements.txt (line 1)) (0.12.3)
# Requirement already satisfied: certifi in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from httpx>=0.23.0->fastapi->-r requirements.txt (line 1)) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from httpx>=0.23.0->fastapi->-r requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: h2<5,>=3 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from httpx[http2]<0.28.0,>=0.27.0->hume[stream]->-r requirements.txt (line 5)) (4.1.0)
# Requirement already satisfied: setuptools in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from imageio-ffmpeg>=0.2.0->moviepy->-r requirements.txt (line 7)) (69.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from jinja2>=2.11.2->fastapi->-r requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: glcontext<3,>=2.5.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from moderngl<6.0.0,>=5.0.0->manim->-r requirements.txt (line 6)) (2.5.0)
# Requirement already satisfied: pyglet>=2.0.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from moderngl-window>=2.0.0->manim->-r requirements.txt (line 6)) (2.0.15)
# Requirement already satisfied: pyrr<1,>=0.10.3 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from moderngl-window>=2.0.0->manim->-r requirements.txt (line 6)) (0.10.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->-r requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->-r requirements.txt (line 1)) (2.18.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from requests<3.0,>=2.8.1->moviepy->-r requirements.txt (line 7)) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from requests<3.0,>=2.8.1->moviepy->-r requirements.txt (line 7)) (2.2.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from rich>=12.0.0->manim->-r requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: Cython in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from screeninfo>=0.7->manim->-r requirements.txt (line 6)) (3.0.10)
# Requirement already satisfied: pyobjc-framework-Cocoa in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from screeninfo>=0.7->manim->-r requirements.txt (line 6)) (10.1)
# Requirement already satisfied: CFFI>=1.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from sounddevice<0.5.0,>=0.4.6->hume[stream]->-r requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: httptools>=0.5.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.12.0->fastapi->-r requirements.txt (line 1)) (0.6.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.12.0->fastapi->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.12.0->fastapi->-r requirements.txt (line 1)) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.12.0->fastapi->-r requirements.txt (line 1)) (0.22.0)
# Requirement already satisfied: pycparser in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from CFFI>=1.0->sounddevice<0.5.0,>=0.4.6->hume[stream]->-r requirements.txt (line 5)) (2.21)
# Requirement already satisfied: hyperframe<7,>=6.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]<0.28.0,>=0.27.0->hume[stream]->-r requirements.txt (line 5)) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]<0.28.0,>=0.27.0->hume[stream]->-r requirements.txt (line 5)) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=12.0.0->manim->-r requirements.txt (line 6)) (0.1.0)
# Requirement already satisfied: multipledispatch in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from pyrr<1,>=0.10.3->moderngl-window>=2.0.0->manim->-r requirements.txt (line 6)) (0.6.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->-r requirements.txt (line 1)) (1.5.4)
# Requirement already satisfied: pyobjc-core>=10.1 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from pyobjc-framework-Cocoa->screeninfo>=0.7->manim->-r requirements.txt (line 6)) (10.1)
# Requirement already satisfied: six in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from multipledispatch->pyrr<1,>=0.10.3->moderngl-window>=2.0.0->manim->-r requirements.txt (line 6)) (1.16.0)
# Downloading openai-1.35.3-py3-none-any.whl (327 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.4/327.4 kB 196.6 kB/s eta 0:00:001m193.3 kB/s eta 0:00:01
# Installing collected packages: openai
# Successfully installed openai-1.35.3

# %%
from scene_generator import SceneGenerator

test_transcriptions = [
    "The quick brown fox jumps over the lazy dog.",
]

sg = SceneGenerator(test_transcriptions)
sg.generate_all_scenes()
# Out:
# 2024-06-22 17:54:31,839 - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '\nYou are an expert teacher of simple and complex topics, similar to 3 Blue 1 Brown. Given a transcription for a video scene, you are to generate Manim code that will create an animation for the scene. The code should be able to run without errors.\n\nTry to be creative in your visualization of the topic. The scene should be engaging and informative. ONLY generate and return the manim code. Nothing else.\n\nThe classname of the root animation should always be VideoScene.\n'}, {'role': 'user', 'content': 'The quick brown fox jumps over the lazy dog.'}], 'model': 'gpt-4-turbo'}}
# 2024-06-22 17:54:31,843 - DEBUG - Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# 2024-06-22 17:54:31,846 - DEBUG - close.started
# 2024-06-22 17:54:31,848 - DEBUG - close.complete
# 2024-06-22 17:54:31,850 - DEBUG - connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# 2024-06-22 17:54:31,869 - DEBUG - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x121314ed0>
# 2024-06-22 17:54:31,869 - DEBUG - start_tls.started ssl_context=<ssl.SSLContext object at 0x121286690> server_hostname='api.openai.com' timeout=5.0
# 2024-06-22 17:54:31,885 - DEBUG - start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x141200e50>
# 2024-06-22 17:54:31,886 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2024-06-22 17:54:31,888 - DEBUG - send_request_headers.complete
# 2024-06-22 17:54:31,888 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2024-06-22 17:54:31,889 - DEBUG - send_request_body.complete
# 2024-06-22 17:54:31,890 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2024-06-22 17:54:43,017 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sun, 23 Jun 2024 00:54:43 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'openai-organization', b'ucb-ai-hackathon-june2024198'), (b'openai-processing-ms', b'10894'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'800000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'799853'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'11ms'), (b'x-request-id', b'c75d6564046e00230a71abbdbd1e7f39'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'898081e23806cf76-SJC'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# 2024-06-22 17:54:43,019 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-06-22 17:54:43,020 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2024-06-22 17:54:43,022 - DEBUG - receive_response_body.complete
# 2024-06-22 17:54:43,023 - DEBUG - response_closed.started
# 2024-06-22 17:54:43,023 - DEBUG - response_closed.complete
# 2024-06-22 17:54:43,024 - DEBUG - HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Sun, 23 Jun 2024 00:54:43 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'openai-organization': 'ucb-ai-hackathon-june2024198', 'openai-processing-ms': '10894', 'openai-version': '2020-10-01', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '800000', 'x-ratelimit-remaining-requests': '9999', 'x-ratelimit-remaining-tokens': '799853', 'x-ratelimit-reset-requests': '6ms', 'x-ratelimit-reset-tokens': '11ms', 'x-request-id': 'c75d6564046e00230a71abbdbd1e7f39', 'cf-cache-status': 'DYNAMIC', 'server': 'cloudflare', 'cf-ray': '898081e23806cf76-SJC', 'content-encoding': 'br', 'alt-svc': 'h3=":443"; ma=86400'})
# 2024-06-22 17:54:43,024 - DEBUG - request_id: c75d6564046e00230a71abbdbd1e7f39
# 2024-06-22 17:54:43,026 - INFO - Generated response: ChatCompletion(id='chatcmpl-9d5mybeWqMFT3EXE2EBNdcSqdagQg', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```python\nfrom manim import *\n\nclass VideoScene(Scene):\n    def construct(self):\n        # Text setup for the narration text\n        description_text = Text("The quick brown fox jumps over the lazy dog.", font_size=40).to_edge(UP)\n        \n        # Creating text objects for fox and dog\n        fox_text = Text("Fox", color=ORANGE, font_size=36).shift(LEFT * 4 + UP * 2)\n        dog_text = Text("Dog", color=GRAY, font_size=36).shift(RIGHT * 4 + DOWN * 1)\n        \n        # Creating visual representation - simple shapes\n        fox_shape = Circle(color=ORANGE, fill_opacity=0.5).shift(LEFT * 4 + UP * 1)\n        dog_shape = Circle(color=GRAY, fill_opacity=0.5).shift(RIGHT * 4)\n        \n        # Animation of fox jumping over the dog\n        fox_jump_path = Arc(radius=3, angle=-3.14, start_angle=-1.57).shift(UP * 0.5)\n        jumping_fox = VGroup(fox_text, fox_shape)\n\n        # Adding elements to the scene\n        self.play(FadeIn(description_text))\n        self.wait(0.5)\n        \n        self.play(\n            FadeIn(fox_text), FadeIn(fox_text), \n            FadeIn(fox_shape), FadeIn(fox_shape),\n            FadeIn(dog_text), FadeIn(dog_text),\n            FadeIn(dog_shape), FadeIn(dog_shape)\n        )\n        self.wait(0.5)\n        \n        self.play(MoveAlongPath(jumping_fox, fox_jump_path))\n        self.wait(0.5)\n\n        # Final scene\n        self.play(FadeOut(VGroup(*self.mobjects)))\n        self.wait(0.5)\n```', role='assistant', function_call=None, tool_calls=None))], created=1719104072, model='gpt-4-turbo-2024-04-09', object='chat.completion', service_tier=None, system_fingerprint='fp_9d7f5c6195', usage=CompletionUsage(completion_tokens=387, prompt_tokens=119, total_tokens=506))
# 2024-06-22 17:54:43,028 - ERROR - Error writing to file: [Errno 2] No such file or directory: 'generated/b9757a01-5d7b-4737-89ae-61e38153e496/video.py'
# 2024-06-22 17:54:43,028 - ERROR - Scene could not be generated for: The quick brown fox jumps over the lazy dog.
# 2024-06-22 17:54:43,029 - ERROR - No scenes were successfully generated.
