# %%
# !pip install -r requirements.txt
# Out:
# Collecting fastapi (from -r requirements.txt (line 1))
#   Using cached fastapi-0.111.0-py3-none-any.whl.metadata (25 kB)
# Collecting uvicorn (from -r requirements.txt (line 2))
#   Using cached uvicorn-0.30.1-py3-none-any.whl.metadata (6.3 kB)
# Collecting asyncio (from -r requirements.txt (line 3))
#   Using cached asyncio-3.4.3-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dotenv in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (0.21.0)
# Collecting manim (from -r requirements.txt (line 6))
#   Using cached manim-0.18.1-py3-none-any.whl.metadata (10 kB)
# Collecting moviepy (from -r requirements.txt (line 7))
#   Using cached moviepy-1.0.3.tar.gz (388 kB)
#   Preparing metadata (setup.py) ... done
# Collecting hume[stream] (from -r requirements.txt (line 5))
#   Using cached hume-0.7.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi->-r requirements.txt (line 1))
#   Using cached starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from fastapi->-r requirements.txt (line 1)) (2.5.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from fastapi->-r requirements.txt (line 1)) (4.11.0)
# Collecting fastapi-cli>=0.0.2 (from fastapi->-r requirements.txt (line 1))
#   Using cached fastapi_cli-0.0.4-py3-none-any.whl.metadata (7.0 kB)
# Collecting httpx>=0.23.0 (from fastapi->-r requirements.txt (line 1))
#   Using cached httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: jinja2>=2.11.2 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from fastapi->-r requirements.txt (line 1)) (3.1.3)
# Collecting python-multipart>=0.0.7 (from fastapi->-r requirements.txt (line 1))
#   Using cached python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from fastapi->-r requirements.txt (line 1)) (5.4.0)
# Collecting orjson>=3.2.1 (from fastapi->-r requirements.txt (line 1))
#   Downloading orjson-3.10.5-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 322.0 kB/s eta 0:00:00 kB/s eta 0:00:01
# Collecting email_validator>=2.0.0 (from fastapi->-r requirements.txt (line 1))
#   Using cached email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: click>=7.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from uvicorn->-r requirements.txt (line 2)) (8.1.7)
# Collecting h11>=0.8 (from uvicorn->-r requirements.txt (line 2))
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting eval-type-backport<0.3.0,>=0.2.0 (from hume[stream]->-r requirements.txt (line 5))
#   Using cached eval_type_backport-0.2.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 (from fastapi->-r requirements.txt (line 1))
#   Using cached pydantic-2.7.4-py3-none-any.whl.metadata (109 kB)
# Collecting pydub<0.26.0,>=0.25.1 (from hume[stream]->-r requirements.txt (line 5))
#   Using cached pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting simpleaudio<2.0.0,>=1.0.4 (from hume[stream]->-r requirements.txt (line 5))
#   Using cached simpleaudio-1.0.4.tar.gz (2.0 MB)
#   Preparing metadata (setup.py) ... done
# Collecting sounddevice<0.5.0,>=0.4.6 (from hume[stream]->-r requirements.txt (line 5))
#   Using cached sounddevice-0.4.7-py3-none-macosx_10_6_x86_64.macosx_10_6_universal2.whl.metadata (1.4 kB)
# Collecting websockets<13.0,>=12.0 (from hume[stream]->-r requirements.txt (line 5))
#   Downloading websockets-12.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: Pillow>=9.1 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (10.3.0)
# Requirement already satisfied: Pygments>=2.0.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (2.15.1)
# Collecting cloup>=2.0.0 (from manim->-r requirements.txt (line 6))
#   Using cached cloup-3.0.5-py2.py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: decorator>=4.3.2 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (5.1.1)
# Collecting isosurfaces>=0.1.0 (from manim->-r requirements.txt (line 6))
#   Using cached isosurfaces-0.1.2-py3-none-any.whl.metadata (3.3 kB)
# Collecting manimpango<1.0.0,>=0.5.0 (from manim->-r requirements.txt (line 6))
#   Using cached ManimPango-0.5.0.tar.gz (4.1 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting mapbox-earcut>=1.0.0 (from manim->-r requirements.txt (line 6))
#   Downloading mapbox_earcut-1.0.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.0 kB)
# Collecting moderngl<6.0.0,>=5.0.0 (from manim->-r requirements.txt (line 6))
#   Downloading moderngl-5.10.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.2 kB)
# Collecting moderngl-window>=2.0.0 (from manim->-r requirements.txt (line 6))
#   Using cached moderngl_window-2.4.6-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: networkx>=2.6 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (3.1)
# Requirement already satisfied: numpy>=1.26 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (1.26.4)
# Collecting pycairo<2.0.0,>=1.13 (from manim->-r requirements.txt (line 6))
#   Using cached pycairo-1.26.1.tar.gz (346 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: rich>=12.0.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (13.3.5)
# Requirement already satisfied: scipy>=1.6.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (1.13.0)
# Collecting screeninfo>=0.7 (from manim->-r requirements.txt (line 6))
#   Using cached screeninfo-0.8.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting skia-pathops>=0.7.0 (from manim->-r requirements.txt (line 6))
#   Downloading skia_pathops-0.8.0.post1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting srt>=3.0.0 (from manim->-r requirements.txt (line 6))
#   Using cached srt-3.5.3.tar.gz (28 kB)
#   Preparing metadata (setup.py) ... done
# Collecting svgelements>=1.8.0 (from manim->-r requirements.txt (line 6))
#   Using cached svgelements-1.9.6-py2.py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: tqdm>=4.0.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (4.66.2)
# Requirement already satisfied: watchdog>=2.0.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from manim->-r requirements.txt (line 6)) (2.1.6)
# Collecting decorator>=4.3.2 (from manim->-r requirements.txt (line 6))
#   Using cached decorator-4.4.2-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: imageio<3.0,>=2.5 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from moviepy->-r requirements.txt (line 7)) (2.33.1)
# Collecting imageio_ffmpeg>=0.2.0 (from moviepy->-r requirements.txt (line 7))
#   Using cached imageio-ffmpeg-0.5.1.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests<3.0,>=2.8.1 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from moviepy->-r requirements.txt (line 7)) (2.31.0)
# Collecting proglog<=1.0.0 (from moviepy->-r requirements.txt (line 7))
#   Using cached proglog-0.1.10-py3-none-any.whl.metadata (639 bytes)
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi->-r requirements.txt (line 1))
#   Using cached dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: idna>=2.0.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from email_validator>=2.0.0->fastapi->-r requirements.txt (line 1)) (3.7)
# Collecting typer>=0.12.3 (from fastapi-cli>=0.0.2->fastapi->-r requirements.txt (line 1))
#   Using cached typer-0.12.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: anyio in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from httpx>=0.23.0->fastapi->-r requirements.txt (line 1)) (4.2.0)
# Requirement already satisfied: certifi in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from httpx>=0.23.0->fastapi->-r requirements.txt (line 1)) (2024.2.2)
# Collecting httpcore==1.* (from httpx>=0.23.0->fastapi->-r requirements.txt (line 1))
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: sniffio in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from httpx>=0.23.0->fastapi->-r requirements.txt (line 1)) (1.3.0)
# Collecting h2<5,>=3 (from httpx[http2]<0.28.0,>=0.27.0->hume[stream]->-r requirements.txt (line 5))
#   Using cached h2-4.1.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: setuptools in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from imageio_ffmpeg>=0.2.0->moviepy->-r requirements.txt (line 7)) (69.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from jinja2>=2.11.2->fastapi->-r requirements.txt (line 1)) (2.1.3)
# Collecting glcontext<3,>=2.5.0 (from moderngl<6.0.0,>=5.0.0->manim->-r requirements.txt (line 6))
#   Using cached glcontext-2.5.0.tar.gz (16 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pyglet>=2.0.0 (from moderngl-window>=2.0.0->manim->-r requirements.txt (line 6))
#   Using cached pyglet-2.0.15-py3-none-any.whl.metadata (7.8 kB)
# Collecting pyrr<1,>=0.10.3 (from moderngl-window>=2.0.0->manim->-r requirements.txt (line 6))
#   Using cached pyrr-0.10.3-py3-none-any.whl.metadata (832 bytes)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->-r requirements.txt (line 1)) (0.6.0)
# Collecting pydantic-core==2.18.4 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->-r requirements.txt (line 1))
#   Downloading pydantic_core-2.18.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from requests<3.0,>=2.8.1->moviepy->-r requirements.txt (line 7)) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from requests<3.0,>=2.8.1->moviepy->-r requirements.txt (line 7)) (2.2.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from rich>=12.0.0->manim->-r requirements.txt (line 6)) (2.2.0)
# Collecting Cython (from screeninfo>=0.7->manim->-r requirements.txt (line 6))
#   Using cached Cython-3.0.10-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pyobjc-framework-Cocoa in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from screeninfo>=0.7->manim->-r requirements.txt (line 6)) (10.1)
# Requirement already satisfied: CFFI>=1.0 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from sounddevice<0.5.0,>=0.4.6->hume[stream]->-r requirements.txt (line 5)) (1.16.0)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.12.0->fastapi->-r requirements.txt (line 1))
#   Downloading httptools-0.6.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.6 kB)
# Requirement already satisfied: pyyaml>=5.1 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.12.0->fastapi->-r requirements.txt (line 1)) (6.0.1)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.12.0->fastapi->-r requirements.txt (line 1))
#   Downloading uvloop-0.19.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.12.0->fastapi->-r requirements.txt (line 1))
#   Downloading watchfiles-0.22.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Requirement already satisfied: pycparser in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from CFFI>=1.0->sounddevice<0.5.0,>=0.4.6->hume[stream]->-r requirements.txt (line 5)) (2.21)
# Collecting hyperframe<7,>=6.0 (from h2<5,>=3->httpx[http2]<0.28.0,>=0.27.0->hume[stream]->-r requirements.txt (line 5))
#   Using cached hyperframe-6.0.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting hpack<5,>=4.0 (from h2<5,>=3->httpx[http2]<0.28.0,>=0.27.0->hume[stream]->-r requirements.txt (line 5))
#   Using cached hpack-4.0.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: mdurl~=0.1 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=12.0.0->manim->-r requirements.txt (line 6)) (0.1.0)
# Requirement already satisfied: multipledispatch in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from pyrr<1,>=0.10.3->moderngl-window>=2.0.0->manim->-r requirements.txt (line 6)) (0.6.0)
# Collecting shellingham>=1.3.0 (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->-r requirements.txt (line 1))
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: pyobjc-core>=10.1 in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from pyobjc-framework-Cocoa->screeninfo>=0.7->manim->-r requirements.txt (line 6)) (10.1)
# Requirement already satisfied: six in /Users/krishshah/anaconda3/lib/python3.11/site-packages (from multipledispatch->pyrr<1,>=0.10.3->moderngl-window>=2.0.0->manim->-r requirements.txt (line 6)) (1.16.0)
# Using cached fastapi-0.111.0-py3-none-any.whl (91 kB)
# Using cached uvicorn-0.30.1-py3-none-any.whl (62 kB)
# Using cached asyncio-3.4.3-py3-none-any.whl (101 kB)
# Using cached manim-0.18.1-py3-none-any.whl (585 kB)
# Using cached cloup-3.0.5-py2.py3-none-any.whl (54 kB)
# Using cached decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Using cached email_validator-2.2.0-py3-none-any.whl (33 kB)
# Using cached eval_type_backport-0.2.0-py3-none-any.whl (5.9 kB)
# Using cached fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Using cached isosurfaces-0.1.2-py3-none-any.whl (11 kB)
# Downloading mapbox_earcut-1.0.1-cp311-cp311-macosx_11_0_arm64.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.2/71.2 kB 2.8 MB/s eta 0:00:00
# Downloading moderngl-5.10.0-cp311-cp311-macosx_11_0_arm64.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.7/114.7 kB 5.3 MB/s eta 0:00:00
# Using cached moderngl_window-2.4.6-py3-none-any.whl (370 kB)
# Downloading orjson-3.10.5-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (258 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.7/258.7 kB 8.9 MB/s eta 0:00:00
# Using cached proglog-0.1.10-py3-none-any.whl (6.1 kB)
# Using cached pydantic-2.7.4-py3-none-any.whl (409 kB)
# Downloading pydantic_core-2.18.4-cp311-cp311-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 6.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Using cached python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Using cached screeninfo-0.8.1-py3-none-any.whl (12 kB)
# Downloading skia_pathops-0.8.0.post1-cp311-cp311-macosx_10_9_universal2.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 8.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Using cached sounddevice-0.4.7-py3-none-macosx_10_6_x86_64.macosx_10_6_universal2.whl (108 kB)
# Using cached starlette-0.37.2-py3-none-any.whl (71 kB)
# Using cached svgelements-1.9.6-py2.py3-none-any.whl (137 kB)
# Downloading websockets-12.0-cp311-cp311-macosx_11_0_arm64.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.3/121.3 kB 5.2 MB/s eta 0:00:00
# Using cached hume-0.7.0-py3-none-any.whl (49 kB)
# Using cached dnspython-2.6.1-py3-none-any.whl (307 kB)
# Using cached h2-4.1.0-py3-none-any.whl (57 kB)
# Downloading httptools-0.6.1-cp311-cp311-macosx_10_9_universal2.whl (145 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.9/145.9 kB 6.9 MB/s eta 0:00:00
# Using cached pyglet-2.0.15-py3-none-any.whl (884 kB)
# Using cached pyrr-0.10.3-py3-none-any.whl (46 kB)
# Using cached typer-0.12.3-py3-none-any.whl (47 kB)
# Downloading uvloop-0.19.0-cp311-cp311-macosx_10_9_universal2.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 7.4 MB/s eta 0:00:00m eta 0:00:010:01:01m
# Downloading watchfiles-0.22.0-cp311-cp311-macosx_11_0_arm64.whl (391 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 391.2/391.2 kB 5.0 MB/s eta 0:00:00m eta 0:00:0100:01
# Using cached Cython-3.0.10-py2.py3-none-any.whl (1.2 MB)
# Using cached hpack-4.0.0-py3-none-any.whl (32 kB)
# Using cached hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Building wheels for collected packages: moviepy, imageio_ffmpeg, manimpango, pycairo, simpleaudio, srt, glcontext
#   Building wheel for moviepy (setup.py) ... done
#   Created wheel for moviepy: filename=moviepy-1.0.3-py3-none-any.whl size=110721 sha256=10a1116cfc099e360b4fdf893ad02b56811bf12d9bbc3df44c424abaef8dc0a0
#   Stored in directory: /Users/krishshah/Library/Caches/pip/wheels/83/b1/d9/119ef7c144b44d591ec0a9a140465133c23ea95d2a161184ba
#   Building wheel for imageio_ffmpeg (setup.py) ... done
#   Created wheel for imageio_ffmpeg: filename=imageio_ffmpeg-0.5.1-py3-none-any.whl size=16724 sha256=0ab76842007784e2890f0911bb5a5f1cfbab1cac0911c5d0ed649fcbd746a575
#   Stored in directory: /Users/krishshah/Library/Caches/pip/wheels/59/07/0d/8c65b2ed75907f876d8fe99a72b80687371f65d8166b31d8e2
#   Building wheel for manimpango (pyproject.toml) ... done
#   Created wheel for manimpango: filename=ManimPango-0.5.0-cp311-cp311-macosx_11_0_arm64.whl size=92106 sha256=6d91d75f1bc9242b264df53487a5abae5f6bb362210b5ed97565ad5ad04bfe85
#   Stored in directory: /Users/krishshah/Library/Caches/pip/wheels/81/3b/be/eb179a2c3c3853a43bd2a912042fe2b5bf1e2bc0aa542668a0
#   Building wheel for pycairo (pyproject.toml) ... done
#   Created wheel for pycairo: filename=pycairo-1.26.1-cp311-cp311-macosx_11_0_arm64.whl size=130528 sha256=d3665a832efddb1af7d0a9810984cc9979585c052733fc6ce33a949da59aa0b0
#   Stored in directory: /Users/krishshah/Library/Caches/pip/wheels/1d/66/b0/a9f835ae730434d050c01e59db2f4252c2fe9ea253c71ed9fa
#   Building wheel for simpleaudio (setup.py) ... done
#   Created wheel for simpleaudio: filename=simpleaudio-1.0.4-cp311-cp311-macosx_11_0_arm64.whl size=2036378 sha256=7b917067c9114bea932ee82994af3e324a4ef0f28e67aa37eade57b43007e93c
#   Stored in directory: /Users/krishshah/Library/Caches/pip/wheels/44/74/11/9d2cf6ddf5d0dcc7750484a371b92fdb036f5496d1d4b42d08
#   Building wheel for srt (setup.py) ... done
#   Created wheel for srt: filename=srt-3.5.3-py3-none-any.whl size=22428 sha256=e827f7a198690730d2cb34851a24b8b3e60d40f8f675cb26b2a4ef07bac3a070
#   Stored in directory: /Users/krishshah/Library/Caches/pip/wheels/1f/43/f1/23ee9119497fcb57d9f7046fbf34c6d9027c46a1fa7824cf08
#   Building wheel for glcontext (pyproject.toml) ... done
#   Created wheel for glcontext: filename=glcontext-2.5.0-cp311-cp311-macosx_11_0_arm64.whl size=9357 sha256=d8a5e88a875e77f01db250bfa0cbc4a02a4cf0ac9c0bb653ab4da174dbab6561
#   Stored in directory: /Users/krishshah/Library/Caches/pip/wheels/0f/08/b0/063197400d6f23e8c47f822d864555bc3bc3fea3ddb7085af9
# Successfully built moviepy imageio_ffmpeg manimpango pycairo simpleaudio srt glcontext
# Installing collected packages: svgelements, simpleaudio, pydub, glcontext, asyncio, websockets, uvloop, srt, skia-pathops, shellingham, python-multipart, pyglet, pydantic-core, pycairo, proglog, orjson, moderngl, mapbox-earcut, manimpango, isosurfaces, imageio_ffmpeg, hyperframe, httptools, hpack, h11, eval-type-backport, dnspython, decorator, Cython, cloup, watchfiles, uvicorn, starlette, sounddevice, screeninfo, pyrr, pydantic, moviepy, httpcore, h2, email_validator, typer, moderngl-window, httpx, manim, fastapi-cli, hume, fastapi
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.14.6
#     Uninstalling pydantic_core-2.14.6:
#       Successfully uninstalled pydantic_core-2.14.6
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.1.1
#     Uninstalling decorator-5.1.1:
#       Successfully uninstalled decorator-5.1.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.5.3
#     Uninstalling pydantic-2.5.3:
#       Successfully uninstalled pydantic-2.5.3
# Successfully installed Cython-3.0.10 asyncio-3.4.3 cloup-3.0.5 decorator-4.4.2 dnspython-2.6.1 email_validator-2.2.0 eval-type-backport-0.2.0 fastapi-0.111.0 fastapi-cli-0.0.4 glcontext-2.5.0 h11-0.14.0 h2-4.1.0 hpack-4.0.0 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 hume-0.7.0 hyperframe-6.0.1 imageio_ffmpeg-0.5.1 isosurfaces-0.1.2 manim-0.18.1 manimpango-0.5.0 mapbox-earcut-1.0.1 moderngl-5.10.0 moderngl-window-2.4.6 moviepy-1.0.3 orjson-3.10.5 proglog-0.1.10 pycairo-1.26.1 pydantic-2.7.4 pydantic-core-2.18.4 pydub-0.25.1 pyglet-2.0.15 pyrr-0.10.3 python-multipart-0.0.9 screeninfo-0.8.1 shellingham-1.5.4 simpleaudio-1.0.4 skia-pathops-0.8.0.post1 sounddevice-0.4.7 srt-3.5.3 starlette-0.37.2 svgelements-1.9.6 typer-0.12.3 uvicorn-0.30.1 uvloop-0.19.0 watchfiles-0.22.0 websockets-12.0

# %%
from scene_generator import SceneGenerator

test_transcriptions = [
    "The quick brown fox jumps over the lazy dog.",
]

sg = SceneGenerator(test_transcriptions)
sg.generate_all_scenes()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from scene_generator import SceneGenerator
#       3 test_transcriptions = [
#       4     "The quick brown fox jumps over the lazy dog.",
#       5 ]
#       7 sg = SceneGenerator(test_transcriptions)
#
# File ~/Code/3brown1blue/backend/scene_generator.py:3
#       1 from manim import *
#       2 import uuid
# ----> 3 from client import client
#       4 from backend.logger import logger
#       5 import os
#
# File ~/Code/3brown1blue/backend/client.py:1
# ----> 1 from openai import OpenAI
#       3 client = OpenAI()
#
# ModuleNotFoundError: No module named 'openai'
